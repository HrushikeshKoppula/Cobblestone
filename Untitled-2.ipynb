# %% [markdown]
# Data from nord pool

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('day_aheadcsv.csv')

# %%
data.head()
# Out:
#   Delivery period ( EET )  01-09-2024  02-09-2024  03-09-2024  04-09-2024  \
# 0             01:00 02:00       73.12       79.25       83.72       90.01
# 1           02:00 - 03:00       65.48       80.86       77.04       85.14
# 2             03:00 04:00       59.38       79.13       77.03       81.04
# 3           04:00 - 05:00       50.61       76.82       78.13       78.60
# 4             05:00 06:00       49.39       76.81       77.04       77.00
#
#    05-09-2024  06-09-2024  07-09-2024  08-09-2024
# 0       86.26       63.74       94.14       98.93
# 1       81.72       57.75       85.02       87.55
# 2       77.44       54.25       80.88       82.91
# 3       73.67       53.66       74.04       78.36
# 4       67.32       49.81       72.79       74.35

# %%
type(data['Delivery period ( EET )'][0])
# Out:
# str

# %%
len(data)
# Out:
# 24

# %%
X = []
for i in range(0,8):
    X.append(list(range(i*24+1,i*24+25)))

# %%
print(X[7])
# Out:
# [169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192]

# %%
plt.figure(dpi=250, figsize=(40, 5))
plt.plot(X[0], data["01-09-2024"])
plt.plot(X[1], data["02-09-2024"])
plt.plot(X[2], data["03-09-2024"])
plt.plot(X[3], data["04-09-2024"])
plt.plot(X[4], data["05-09-2024"])
plt.plot(X[5], data["06-09-2024"])
plt.plot(X[6], data["07-09-2024"])
plt.plot(X[7], data["08-09-2024"])

# %%
X = range(1,193)

# %%
Y = []
Y.append(data["01-09-2024"])
Y.append(data["02-09-2024"])
Y.append(data["03-09-2024"])
Y.append(data["04-09-2024"])
Y.append(data["05-09-2024"])
Y.append(data["06-09-2024"])
Y.append(data["07-09-2024"])
Y.append(data["08-09-2024"])

# %%
print(len(Y))
# Out:
# 2

# %%
Y = data["01-09-2024"] +data["02-09-2024"] +data["03-09-2024"] +data["04-09-2024"] +data["05-09-2024"] +data["06-09-2024"] +data["07-09-2024"] +data["08-09-2024"]

# %%
print(Y)
# Out:
# 0     669.17
# 1     620.56
# 2     592.06
# 3     563.89
# 4     544.51
# 5     551.02
# 6     603.00
# 7     682.85
# 8     722.38
# 9     682.70
# 10    663.63
# 11    639.48
# 12    610.98
# 13    591.80
# 14    554.26
# 15    542.82
# 16    540.79
# 17    645.18
# 18    776.95
# 19    875.37
# 20    878.74
# 21    814.53
# 22    723.58
# 23    663.25
# dtype: float64

# %%
Y = pd.concat([data["01-09-2024"], data["02-09-2024"], data["03-09-2024"], data["04-09-2024"], data["05-09-2024"], data["06-09-2024"], data["07-09-2024"], data["08-09-2024"]])

# %%
print(Y)
# Out:
# 0      73.12
# 1      65.48
# 2      59.38
# 3      50.61
# 4      49.39
#        ...
# 19    103.70
# 20    106.91
# 21     95.04
# 22     83.38
# 23     79.03
# Length: 192, dtype: float64

# %%
plt.figure(dpi=250,figsize=(20,5))
plt.plot(X,Y)

# %%
plt.bar(X,Y)
# Out:
# <BarContainer object of 192 artists>
